# %%
from pyspark.sql import SparkSession
from pysparkling import *

ss = SparkSession.builder.getOrCreate()
hc = H2OContext.getOrCreate()
# Out:
# Sparkling Water Context:
#  * Sparkling Water Version: 3.28.0.1-1-2.4
#  * H2O name: sparkling-water-dwoodbridge_local-1579037732703
#  * cluster size: 1
#  * list of used nodes:
#   (executorId, host, port)
#   ------------------------
#   (driver,10.1.133.151,54325)
#   ------------------------
#
#   Open H2O Flow in browser: http://10.1.133.151:54325 (CMD + click in Mac OSX)

# %% [markdown]
# ## Create DataFrame from parquet file and convert to H2OFrame

# %% [markdown]
# ### Parquet files with nested structures are not supported.

# %%
adult_train_df = h2o.import_file("../../spark-warehouse/adulttrain")
# Out:
# ---------------------------------------------------------------------------
# H2OServerError                            Traceback (most recent call last)
# <ipython-input-38-80398985cc1f> in <module>
# ----> 1 adult_train_df = h2o.import_file("../../spark-warehouse/adulttrain")
#
# ~/anaconda3/envs/DistributedComputing/lib/python3.7/site-packages/h2o/h2o.py in import_file(path, destination_frame, parse, header, sep, col_names, col_types, na_strings, pattern, skipped_columns, custom_non_data_line_markers)
#     474     else:
#     475         return H2OFrame()._import_parse(path, pattern, destination_frame, header, sep, col_names, col_types, na_strings,
# --> 476                                         skipped_columns, custom_non_data_line_markers)
#     477
#     478
#
# ~/anaconda3/envs/DistributedComputing/lib/python3.7/site-packages/h2o/frame.py in _import_parse(self, path, pattern, destination_frame, header, separator, column_names, column_types, na_strings, skipped_columns, custom_non_data_line_markers)
#     428         rawkey = h2o.lazy_import(path, pattern)
#     429         self._parse(rawkey, destination_frame, header, separator, column_names, column_types, na_strings,
# --> 430                     skipped_columns, custom_non_data_line_markers)
#     431         return self
#     432
#
# ~/anaconda3/envs/DistributedComputing/lib/python3.7/site-packages/h2o/frame.py in _parse(self, rawkey, destination_frame, header, separator, column_names, column_types, na_strings, skipped_columns, custom_non_data_line_markers)
#     442                na_strings=None, skipped_columns=None, custom_non_data_line_markers = None):
#     443         setup = h2o.parse_setup(rawkey, destination_frame, header, separator, column_names, column_types, na_strings,
# --> 444                                 skipped_columns, custom_non_data_line_markers)
#     445         return self._parse_raw(setup)
#     446
#
# ~/anaconda3/envs/DistributedComputing/lib/python3.7/site-packages/h2o/h2o.py in parse_setup(raw_frames, destination_frame, header, separator, column_names, column_types, na_strings, skipped_columns, custom_non_data_line_markers)
#     767         kwargs["custom_non_data_line_markers"] = custom_non_data_line_markers;
#     768
# --> 769     j = api("POST /3/ParseSetup", data=kwargs)
#     770     if "warnings" in j and j["warnings"]:
#     771         for w in j["warnings"]:
#
# ~/anaconda3/envs/DistributedComputing/lib/python3.7/site-packages/h2o/h2o.py in api(endpoint, data, json, filename, save_to)
#     121     # type checks are performed in H2OConnection class
#     122     _check_connection()
# --> 123     return h2oconn.request(endpoint, data=data, json=json, filename=filename, save_to=save_to)
#     124
#     125
#
# ~/anaconda3/envs/DistributedComputing/lib/python3.7/site-packages/h2o/backend/connection.py in request(self, endpoint, data, json, filename, save_to)
#     476                 save_to = save_to(resp)
#     477             self._log_end_transaction(start_time, resp)
# --> 478             return self._process_response(resp, save_to)
#     479
#     480         except (requests.exceptions.ConnectionError, requests.exceptions.HTTPError) as e:
#
# ~/anaconda3/envs/DistributedComputing/lib/python3.7/site-packages/h2o/backend/connection.py in _process_response(response, save_to)
#     827         # Note that it is possible to receive valid H2OErrorV3 object in this case, however it merely means the server
#     828         # did not provide the correct status code.
# --> 829         raise H2OServerError("HTTP %d %s:\n%r" % (status_code, response.reason, data))
#     830
#     831
#
# H2OServerError: HTTP 500 Server Error:
# Server error water.util.DistributedException:
#   Error: DistributedException from 10.1.133.151/10.1.133.151:54325: 'Parquet files with nested structures are not supported.'
#   Request: None

# %%
adult_train_df = ss.read.parquet("../../spark-warehouse/adulttrain")

# %%
adult_train_h2o = hc.as_h2o_frame(adult_train_df, "adult_train")

# %%
adult_train_h2o.summary()

# %%
# Change it to enum
adult_train_h2o["label"] = adult_train_h2o["label"].asfactor()

# %%
adult_train_h2o.summary()
# Out:
# <table>
# <thead>
# <tr><th>       </th><th>features0         </th><th>features1         </th><th>features2        </th><th>features3         </th><th>features4         </th><th>features5         </th><th>features6          </th><th>features7          </th><th>features8          </th><th>features9          </th><th>features10          </th><th>features11          </th><th>features12           </th><th>features13            </th><th>features14         </th><th>features15         </th><th>features16        </th><th>features17          </th><th>features18          </th><th>features19         </th><th>features20         </th><th>features21         </th><th>features22          </th><th>features23          </th><th>features24          </th><th>features25          </th><th>features26          </th><th>features27          </th><th>features28          </th><th>features29           </th><th>features30         </th><th>features31         </th><th>features32         </th><th>features33          </th><th>features34         </th><th>features35          </th><th>features36           </th><th>features37         </th><th>features38         </th><th>features39         </th><th>features40         </th><th>features41        </th><th>features42         </th><th>features43         </th><th>features44         </th><th>features45         </th><th>features46         </th><th>features47          </th><th>features48         </th><th>features49          </th><th>features50           </th><th>features51        </th><th>features52         </th><th>features53         </th><th>features54         </th><th>features55          </th><th>features56         </th><th>features57         </th><th>features58          </th><th>features59          </th><th>features60          </th><th>features61           </th><th>features62           </th><th>features63          </th><th>features64          </th><th>features65           </th><th>features66          </th><th>features67          </th><th>features68           </th><th>features69           </th><th>features70           </th><th>features71           </th><th>features72           </th><th>features73           </th><th>features74           </th><th>features75           </th><th>features76           </th><th>features77           </th><th>features78           </th><th>features79           </th><th>features80           </th><th>features81           </th><th>features82           </th><th>features83           </th><th>features84           </th><th>features85           </th><th>features86           </th><th>features87           </th><th>features88           </th><th>features89           </th><th>features90           </th><th>features91           </th><th>features92           </th><th>features93            </th><th>features94           </th><th>features95           </th><th>features96            </th><th>features97  </th><th>features98         </th><th>features99         </th><th>features100         </th><th>features101         </th><th>features102         </th><th>label  </th></tr>
# </thead>
# <tbody>
# <tr><td>type   </td><td>int               </td><td>int               </td><td>int              </td><td>int               </td><td>int               </td><td>int               </td><td>int                </td><td>int                </td><td>int                </td><td>int                </td><td>int                 </td><td>int                 </td><td>int                  </td><td>int                   </td><td>int                </td><td>int                </td><td>int               </td><td>int                 </td><td>int                 </td><td>int                </td><td>int                </td><td>int                </td><td>int                 </td><td>int                 </td><td>int                 </td><td>int                 </td><td>int                 </td><td>int                 </td><td>int                 </td><td>int                  </td><td>int                </td><td>int                </td><td>int                </td><td>int                 </td><td>int                </td><td>int                 </td><td>int                  </td><td>int                </td><td>int                </td><td>int                </td><td>int                </td><td>int               </td><td>int                </td><td>int                </td><td>int                </td><td>int                </td><td>int                </td><td>int                 </td><td>int                </td><td>int                 </td><td>int                  </td><td>int               </td><td>int                </td><td>int                </td><td>int                </td><td>int                 </td><td>int                </td><td>int                </td><td>int                 </td><td>int                 </td><td>int                 </td><td>int                  </td><td>int                  </td><td>int                 </td><td>int                 </td><td>int                  </td><td>int                 </td><td>int                 </td><td>int                  </td><td>int                  </td><td>int                  </td><td>int                  </td><td>int                  </td><td>int                  </td><td>int                  </td><td>int                  </td><td>int                  </td><td>int                  </td><td>int                  </td><td>int                  </td><td>int                  </td><td>int                  </td><td>int                  </td><td>int                  </td><td>int                  </td><td>int                  </td><td>int                  </td><td>int                  </td><td>int                  </td><td>int                  </td><td>int                  </td><td>int                  </td><td>int                  </td><td>int                   </td><td>int                  </td><td>int                  </td><td>int                   </td><td>int         </td><td>int                </td><td>int                </td><td>int                 </td><td>int                 </td><td>int                 </td><td>enum   </td></tr>
# <tr><td>mins   </td><td>17.0              </td><td>0.0               </td><td>0.0              </td><td>12285.0           </td><td>1.0               </td><td>0.0               </td><td>0.0                </td><td>0.0                </td><td>0.0                </td><td>0.0                </td><td>0.0                 </td><td>0.0                 </td><td>0.0                  </td><td>0.0                   </td><td>0.0                </td><td>0.0                </td><td>0.0               </td><td>0.0                 </td><td>0.0                 </td><td>0.0                </td><td>0.0                </td><td>0.0                </td><td>0.0                 </td><td>0.0                 </td><td>0.0                 </td><td>0.0                 </td><td>0.0                 </td><td>0.0                 </td><td>0.0                 </td><td>0.0                  </td><td>0.0                </td><td>0.0                </td><td>0.0                </td><td>0.0                 </td><td>0.0                </td><td>0.0                 </td><td>0.0                  </td><td>0.0                </td><td>0.0                </td><td>0.0                </td><td>0.0                </td><td>0.0               </td><td>0.0                </td><td>0.0                </td><td>0.0                </td><td>0.0                </td><td>0.0                </td><td>0.0                 </td><td>0.0                </td><td>0.0                 </td><td>0.0                  </td><td>0.0               </td><td>0.0                </td><td>0.0                </td><td>0.0                </td><td>0.0                 </td><td>0.0                </td><td>0.0                </td><td>0.0                 </td><td>0.0                 </td><td>0.0                 </td><td>0.0                  </td><td>0.0                  </td><td>0.0                 </td><td>0.0                 </td><td>0.0                  </td><td>0.0                 </td><td>0.0

# %%
adult_valid_df = ss.read.parquet("../../spark-warehouse/adultvalid")
adult_valid_h2o = hc.as_h2o_frame(adult_valid_df, "adult_valid")
adult_valid_h2o["label"] = adult_valid_h2o["label"].asfactor()
adult_valid_h2o.summary()

# %% [markdown]
# ## Apply ML Algorithms
# Algorithm Parameter Details : http://docs.h2o.ai/h2o/latest-stable/h2o-py/docs/_modules/index.html

# %% [markdown]
# ### Define Predictors

# %%
predictors = adult_valid_h2o.names[:]
response = "label"
predictors.remove(response)

# %%
response
# Out:
# 'label'

# %%
adult_valid_h2o.names[:]
# Out:
# ['features0',
#  'features1',
#  'features2',
#  'features3',
#  'features4',
#  'features5',
#  'features6',
#  'features7',
#  'features8',
#  'features9',
#  'features10',
#  'features11',
#  'features12',
#  'features13',
#  'features14',
#  'features15',
#  'features16',
#  'features17',
#  'features18',
#  'features19',
#  'features20',
#  'features21',
#  'features22',
#  'features23',
#  'features24',
#  'features25',
#  'features26',
#  'features27',
#  'features28',
#  'features29',
#  'features30',
#  'features31',
#  'features32',
#  'features33',
#  'features34',
#  'features35',
#  'features36',
#  'features37',
#  'features38',
#  'features39',
#  'features40',
#  'features41',
#  'features42',
#  'features43',
#  'features44',
#  'features45',
#  'features46',
#  'features47',
#  'features48',
#  'features49',
#  'features50',
#  'features51',
#  'features52',
#  'features53',
#  'features54',
#  'features55',
#  'features56',
#  'features57',
#  'features58',
#  'features59',
#  'features60',
#  'features61',
#  'features62',
#  'features63',
#  'features64',
#  'features65',
#  'features66',
#  'features67',
#  'features68',
#  'features69',
#  'features70',
#  'features71',
#  'features72',
#  'features73',
#  'features74',
#  'features75',
#  'features76',
#  'features77',
#  'features78',
#  'features79',
#  'features80',
#  'features81',
#  'features82',
#  'features83',
#  'features84',
#  'features85',
#  'features86',
#  'features87',
#  'features88',
#  'features89',
#  'features90',
#  'features91',
#  'features92',
#  'features93',
#  'features94',
#  'features95',
#  'features96',
#  'features97',
#  'features98',
#  'features99',
#  'features100',
#  'features101',
#  'features102',
#  'label']

# %% [markdown]
# ### Gradient Boosting
# http://docs.h2o.ai/h2o/latest-stable/h2o-py/docs/_modules/h2o/estimators/gbm.html
#
# http://docs.h2o.ai/h2o/latest-stable/h2o-py/docs/modeling.html#h2o.estimators.gbm.H2OGradientBoostingEstimator

# %%
from h2o.estimators.gbm import H2OGradientBoostingEstimator
model_gbm = H2OGradientBoostingEstimator(ntrees=50, max_depth=6, learn_rate=0.1)

model_gbm.train(x=predictors, y=response, training_frame=adult_train_h2o, validation_frame=adult_valid_h2o)
# Out:
# gbm Model Build progress: |███████████████████████████████████████████████| 100%

# %%
model_gbm
# Out:
# Model Details
# =============
# H2OGradientBoostingEstimator :  Gradient Boosting Machine
# Model Key:  GBM_model_python_1579037733400_1
#
#
# Model Summary:
#      number_of_trees  number_of_internal_trees  model_size_in_bytes  \
# 0               50.0                      50.0              33774.0
#
#    min_depth  max_depth  mean_depth  min_leaves  max_leaves  mean_leaves
# 0        6.0        6.0         6.0        40.0        59.0        49.04
# ModelMetricsBinomial: gbm
# ** Reported on train data. **
#
# MSE: 0.0865815579852638
# RMSE: 0.29424744346427856
# LogLoss: 0.27854758842161953
# Mean Per-Class Error: 0.15152835901472628
# AUC: 0.9314634962743049
# AUCPR: 0.8358102017353671
# Gini: 0.8629269925486098
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.3625362201025742:
#                 0       1   Error               Rate
# 0      0  27000.0  2703.0   0.091   (2703.0/29703.0)
# 1      1   2296.0  7015.0  0.2466    (2296.0/9311.0)
# 2  Total  29296.0  9718.0  0.1281   (4999.0/39014.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold         value    idx
# 0                        max f1   0.362536      0.737296  202.0
# 1                        max f2   0.205498      0.811671  267.0
# 2                  max f0point5   0.575904      0.771643  127.0
# 3                  max accuracy   0.420658      0.878992  180.0
# 4                 max precision   0.984218      1.000000    0.0
# 5                    max recall   0.011370      1.000000  396.0
# 6               max specificity   0.984218      1.000000    0.0
# 7              max absolute_mcc   0.420658      0.656855  180.0
# 8    max min_per_class_accuracy   0.282325      0.846848  234.0
# 9   max mean_per_class_accuracy   0.236207      0.848472  254.0
# 10                      max tns   0.984218  29703.000000    0.0
# 13  features42           131.586426           0.017576    0.006826
# 14  features22           120.195503           0.016055    0.006236
# 15  features46            90.277306           0.012059    0.004683
# 16   features3            84.833275           0.011331    0.004401
# 17  features55            73.729515           0.009848    0.003825
# 18  features21            67.953049           0.009077    0.003525
# 19  features19            60.783630           0.008119    0.003153
# See the whole table with table.as_data_frame()

# %%
print(model_gbm.confusion_matrix(valid=True))
#print(model_gbm.)
# Out:
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.32351816532233696:
#                0       1   Error              Rate
# 0      0  6500.0   952.0  0.1278    (952.0/7452.0)
# 1      1   531.0  1845.0  0.2235    (531.0/2376.0)
# 2  Total  7031.0  2797.0  0.1509   (1483.0/9828.0)

# %%
print(model_gbm.auc(train=True))
#print(model_gbm.)
# Out:
# 0.9314634962743049

# %% [markdown]
# ### Deep Learning
# http://docs.h2o.ai/h2o/latest-stable/h2o-py/docs/_modules/h2o/estimators/deeplearning.html
#
# http://docs.h2o.ai/h2o/latest-stable/h2o-py/docs/modeling.html#h2o.estimators.deeplearning.H2ODeepLearningEstimator

# %%
from h2o.estimators.deeplearning import H2ODeepLearningEstimator
model_dl = H2ODeepLearningEstimator(variable_importances=True, loss="Automatic")

model_dl.train(x=predictors, y="label", training_frame=adult_train_h2o, validation_frame=adult_valid_h2o)
# Out:
# deeplearning Model Build progress: |██████████████████████████████████████| 100%

# %%
model_dl
# Out:
# Model Details
# =============
# H2ODeepLearningEstimator :  Deep Learning
# Model Key:  DeepLearning_model_python_1579037733400_54
#
#
# Status of Neuron Layers: predicting label, 2-class classification, bernoulli distribution, CrossEntropy loss, 61,202 weights/biases, 741.8 KB, 390,140 training samples, mini-batch size 1
#      layer  units       type dropout l1 l2   mean_rate    rate_rms momentum  \
# 0        1    102      Input       0
# 1        2    200  Rectifier       0  0  0    0.139009    0.211881        0
# 2        3    200  Rectifier       0  0  0    0.182175    0.207577        0
# 3        4      2    Softmax          0  0  0.00532036  0.00292564        0
#
#    mean_weight weight_rms   mean_bias   bias_rms
# 0
# 1    0.0680567   0.166042    0.317455  0.0768551
# 2   -0.0278763  0.0751946    0.656193   0.168798
# 3 -0.000375141   0.293047  0.00345473   0.187163
# ModelMetricsBinomial: deeplearning
# ** Reported on train data. **
#
# MSE: 0.09476945557221476
# RMSE: 0.30784648052595104
# LogLoss: 0.2979832318313572
# Mean Per-Class Error: 0.163471148575544
# AUC: 0.9183394783483347
# AUCPR: 0.7678308614300883
# Gini: 0.8366789566966695
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.44948319868263914:
#                0       1   Error               Rate
# 0      0  6905.0   740.0  0.0968     (740.0/7645.0)
# 1      1   631.0  1741.0   0.266     (631.0/2372.0)
# 2  Total  7536.0  2481.0  0.1369   (1371.0/10017.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold        value    idx
# 0                        max f1   0.449483     0.717494  184.0
# 1                        max f2   0.220496     0.797845  274.0
# 2                  max f0point5   0.594040     0.731477  130.0
# 3                  max accuracy   0.479211     0.864331  173.0
# 4                 max precision   0.999882     1.000000    0.0
# 5                    max recall   0.000747     1.000000  398.0
# 6               max specificity   0.999882     1.000000    0.0
# 7              max absolute_mcc   0.449483     0.627520  184.0
# 8    max min_per_class_accuracy   0.340103     0.834317  229.0
# 9   max mean_per_class_accuracy   0.292629     0.836529  247.0
# 10                      max tns   0.999882  7645.000000    0.0
# 11                      max fns   0.999882  2302.000000    0.0
# 12                      max fps   0.000217  7645.000000  399.0
# 13                      max tps   0.000747  2372.000000  398.0
# 14                      max tnr   0.999882     1.000000    0.0
# 15                      max fnr   0.999882     0.970489    0.0
# 16                      max fpr   0.000217     1.000000  399.0
# 17                      max tpr   0.000747     1.000000  398.0
# Gains/Lift Table: Avg response rate: 23.68 %, avg score: 25.02 %
#       group  cumulative_data_fraction  lower_threshold      lift  \
# 0         1                  0.
#
#     cumulative_score  capture_rate  cumulative_capture_rate        gain  \
# 0           0.999505      0.041667                 0.041667  313.636364
# 1           0.997214      0.040825                 0.082492  309.415584
# 2           0.988764      0.040825                 0.123316  309.415584
# 3           0.975617      0.040404                 0.163721  301.101928
# 4           0.960153      0.036195                 0.199916  262.987013
# 5           0.885105      0.165404                 0.365320  231.077578
# 6           0.815477      0.129630                 0.494949  158.943089
# 7           0.754709      0.109007                 0.603956  118.191076
# 8           0.650603      0.167508                 0.771465   67.474336
# 9           0.561713      0.104798                 0.876263    4.883355
# 10          0.480395      0.064815                 0.941077  -35.198372
# 11          0.411196      0.037037                 0.978114  -62.970498
# 12          0.355833      0.013889                 0.992003  -86.099796
# 13          0.312280      0.005471                 0.997475  -94.529733
# 14          0.277800      0.002104                 0.999579  -97.896051
# 15          0.250047      0.000421                 1.000000  -99.579210
#
#     cumulative_gain
# 0        313.636364
# 1        311.536687
# 2        310.832049
# 3        308.387171
# 4        299.344050
# 5        265.245538
# 6        229.787365
# 7        201.916674
# 8        157.102562
# 9        119.076802
# 10        88.215488
# 11        63.013551
# 12        41.727127
# 13        24.690687
# 14        11.066859
# 15         0.000000
# Scoring History:
#                timestamp    duration training_speed  epochs  iterations  \
# 0    2020-01-14 14:15:37   0.000 sec           None     0.0           0
# 1    2020-01-14 14:15:42   5.930 sec   8100 obs/sec     1.0           1
# 2    2020-01-14 14:15:51  15.317 sec  11329 obs/sec     4.0           4
# 3    2020-01-14 14:15:57  21.000 sec  12271 obs/sec     6.0           6
# 4    2020-01-14 14:16:03  26.728 sec  12787 obs/sec     8.0           8
# 5    2020-01-14 14:16:08  32.640 sec  13059 obs/sec    10.0          10
# 6    2020-01-14 14:16:09  33.135 sec  13056 obs/sec    10.0          10
#
#     samples  training_rmse  training_logloss  training_r2  ...  \
# 0       0.0            NaN               NaN          NaN  ...
# 1   39014.0       0.323997          0.339550     0.419147  ...
# 2  156056.0       0.310446          0.304616     0.466721  ...
# 3  234084.0       0.307846          0.297983     0.475613  ...
# 4  312112.0       0.307403          0.301051     0.477124  ...
# 5  390140.0       0.304396          0.291857     0.487302  ...
# 6  390140.0       0.307846          0.297983     0.475613  ...
#
#    training_pr_auc  training_lift  training_classification_error  \
# 0              NaN            NaN                            NaN
# 1         0.732864       4.139394                       0.179794
# 2         0.764135       4.181206                       0.146651
# 3         0.767831       4.223019                       0.136867
# 4         0.754838       4.223019                       0.142558
# 5         0.755617       4.223019                       0.134571
# 6         0.767831       4.223019                       0.136867
#
#    validation_rmse  validation_logloss  validation_r2  validation_auc  \
# 0              NaN                 NaN            NaN             NaN
# 1         0.330996            0.348150       0.402336        0.893526
# 2         0.321264            0.323407       0.436965        0.904218
# 3         0.320901            0.321997       0.438236        0.904040
# 4         0.322197            0.331767       0.433692        0.902980
# 5         0.322018            0.327169       0.434321        0.903674
# 6         0.320901            0.321997       0.438236        0.904040
#
#    validation_pr_auc  validation_lift  validation_classification_error
# 0                NaN              NaN                              NaN
# 1           0.720055         4.136364                         0.169516
# 2           0.742320         4.136364                         0.172873
# 3           0.742733         4.136364                         0.168702
# 4           0.734341         4.094582                         0.159341
# 5           0.736375         4.094582                         0.168803
# 6           0.742733         4.136364                         0.168702
#
# [7 rows x 21 columns]
# Variable Importances:
#       variable  relative_importance  scaled_importance  percentage
# 0    features1             1.000000           1.000000    0.029079
# 1   features42             0.585458           0.585458    0.017025
# 2   features31             0.571408           0.571408    0.016616
# 3    features0             0.556395           0.556395    0.016179
# 4   features37             0.511165           0.511165    0.014864
# 5   features40             0.506791           0.506791    0.014737
# 6   features53             0.486875           0.486875    0.014158
# 7   features50             0.478447           0.478447    0.013913
# 8   features32             0.475059           0.475059    0.013814
# 9   features52             0.460709           0.460709    0.013397
# 10  features38             0.454654           0.454654    0.013221
# 11  features39             0.452702           0.452702    0.013164
# 12   features4             0.444636           0.444636    0.012930
# 13  features43             0.435654           0.435654    0.012668
# 14  features92             0.434949           0.434949    0.012648
# 15  features94             0.434277           0.434277    0.012628
# 16  features73             0.427737           0.427737    0.012438
# 17  features13             0.418518           0.418518    0.012170
# 18  features41             0.415607           0.415607    0.012085
# 19  features90             0.412851           0.412851    0.012005
# See the whole table with table.as_data_frame()

# %%
print(model_dl.confusion_matrix(train=True))
#print(model_dl.)
#print(model_dl.)
#print(model_dl.)
# Out:
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.44948319868263914:
#                0       1   Error               Rate
# 0      0  6905.0   740.0  0.0968     (740.0/7645.0)
# 1      1   631.0  1741.0   0.266     (631.0/2372.0)
# 2  Total  7536.0  2481.0  0.1369   (1371.0/10017.0)

# %% [markdown]
# ### XG Boosting
# http://docs.h2o.ai/sparkling-water/2.4/latest-stable/doc/tutorials/sw_xgboost.html
#
# http://docs.h2o.ai/h2o/latest-stable/h2o-py/docs/_modules/h2o/estimators/xgboost.html
#
# http://docs.h2o.ai/h2o/latest-stable/h2o-py/docs/modeling.html#h2o.estimators.xgboost.H2OXGBoostEstimator

# %%
from h2o.estimators.xgboost import H2OXGBoostEstimator
model_xg = H2OXGBoostEstimator()
model_xg.train(x=predictors, y="label", training_frame=adult_train_h2o, validation_frame=adult_valid_h2o)
# Out:
# xgboost Model Build progress: |███████████████████████████████████████████| 100%

# %%
model_xg
# Out:
# Model Details
# =============
# H2OXGBoostEstimator :  XGBoost
# Model Key:  XGBoost_model_python_1579037733400_67
#
#
# Model Summary:
#      number_of_trees
# 0               50.0
# ModelMetricsBinomial: xgboost
# ** Reported on train data. **
#
# MSE: 0.07894676508216392
# RMSE: 0.2809746698230357
# LogLoss: 0.2492833625984321
# Mean Per-Class Error: 0.1355776806790765
# AUC: 0.9443482782558101
# AUCPR: 0.8140927561891335
# Gini: 0.8886965565116203
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.3821819340571379:
#                 0       1   Error               Rate
# 0      0  27139.0  2564.0  0.0863   (2564.0/29703.0)
# 1      1   2064.0  7247.0  0.2217    (2064.0/9311.0)
# 2  Total  29203.0  9811.0  0.1186   (4628.0/39014.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold         value    idx
# 0                        max f1   0
# 15          0.238744      0.000000                 1.000000 -100.000000
#
#     cumulative_gain
# 0        319.009773
# 1        319.009773
# 2        319.009773
# 3        319.009773
# 4        319.009773
# 5        305.049940
# 6        270.679015
# 7        239.868255
# 8        182.918376
# 9        135.736628
# 10        96.198045
# 11        65.756600
# 12        42.656313
# 13        24.973951
# 14        11.109845
# 15         0.000000
# ModelMetricsBinomial: xgboost
# ** Reported on validation data. **
#
# MSE: 0.0898811674324344
# RMSE: 0.29980188030169924
# LogLoss: 0.28173301996096967
# Mean Per-Class Error: 0.15566595910798808
# AUC: 0.9254398182035058
# AUCPR: 0.7849587910467977
# Gini: 0.8508796364070117
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.3193774774670601:
#                0       1   Error              Rate
# 0      0  6469.0   983.0  0.1319    (983.0/7452.0)
# 1      1   479.0  1897.0  0.2016    (479.0/2376.0)
# 2  Total  6948.0  2880.0  0.1488   (1462.0/9828.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold        value    idx
# 0                        max f1   0.319377     0.721842  222.0
# 1                        max f2   0.166974     0.807635  284.0
# 2                  max f0point5   0.671233     0.766256   97.0
# 3                  max accuracy   0.571326     0.869353  132.0
# 4                 max precision   0.998504     1.000000    0.0
# 5                    max recall   0.000492     1.000000  399.0
# 6               max specificity   0.998504     1.000000    0.0
# 7              max absolute_mcc   0.439026     0.627229  176.0
# 8    max min_per_class_accuracy   0.274179     0.840714  241.0
# 9   max mean_per_class_accuracy   0.205790     0.844334  267.0
# 10                      max tns   0.998504  7452.000000    0.0
# 11                      max fns   0.998504  2278.000000    0.0
# 12                      max fps   0.000492  7452.000000  399.0
# 13                      max tps   0.000492  2376.000000  399.0
# 14                      max tnr   0.998504     1.000000    0.0
# 15                      max fnr   0.998504     0.958754    0.0
# 16                      max fpr   0.000492     1.000000  399.0
# 17                      max tpr   0.000492     1.000000  399.0
# Gains/Lift Table: Avg response rate: 24.18 %, avg score: 23.96 %
#       group  cumulative_data_fraction  lower_threshold      lift  \
# 0         1                  0.010073         0.998042  4.136364
# 1         2                  0.020045         0.997235  4.136364
# 2         3                  0.030016         0.995301  4.136364
# 3         4                  0.040090         0.989335  4.136364
# 4         5                  0.050061         0.976312  4.136364
# 5         6                  0.100020         0.757718  3.614053
# 6         7                  0.150081         0.629131  2.883684
# 7         8                  0.200041         0.485320  2.198759
# 8         9                  0.300061         0.307461  1.653704
# 9        10                  0.399980         0.172443  1.053046
# 10       11                  0.500000         0.082529  0.504948
# 11       12                  0.600020         0.036412  0.227226
# 12       13                  0.699939         0.016704  0.088456
# 13       14                  0.799959         0.006879  0.042079
# 14       15                  0.899980         0.001882  0.004208
# 15       16                  1.000000         0.000072  0.008416
#
#     cumulative_lift  response_rate     score  cumulative_response_rate  \
# 0          4.136364       1.000000  0.998502                  1.000000
# 1          4.136364       1.000000  0.997681                  1.000000
# 2          4.136364       1.000000  0.996391                  1.000000
# 3          4.136364       1.000000  0.992950                  1.000000
# 4          4.136364       1.000000  0.982284                  1.000000
# 5          3.875474       0.873727  0.865523                  0.936928
# 6          3.544653       0.697154  0.690046                  0.856949
# 7          3.208522       0.531568  0.555797                  0.775687
# 8          2.690249       0.399797  0.386353                  0.650390
# 9          2.281261       0.254582  0.235349                  0.551514
# 10         1.925926       0.122075  0.123900                  0.465608
# 11         1.642761       0.054934  0.056104                  0.397151
# 12         1.420879       0.021385  0.025267                  0.343509
# 13         1.248485       0.010173  0.011208                  0.301832
# 14         1.110201       0.001017  0.004090                  0.268400
# 15         1.000000       0.002035  0.000903                  0.241758
#
#     cumulative_score  capture_rate  cumulative_capture_rate        gain  \
# 0           0
# See the whole table with table.as_data_frame()
#
# Variable Importances:
#       variable  relative_importance  scaled_importance  percentage
# 0   features30         15357.922852           1.000000    0.352905
# 1    features1          9295.558594           0.605261    0.213600
# 2    features2          3460.376465           0.225315    0.079515
# 3    features0          3416.644531           0.222468    0.078510
# 4    features4          1962.561035           0.127788    0.045097
# 5   features16          1259.400269           0.082003    0.028939
# 6   features39           992.366150           0.064616    0.022803
# 7   features17           947.249451           0.061678    0.021767
# 8    features3           859.552795           0.055968    0.019751
# 9   features37           565.990234           0.036853    0.013006
# 10  features23           475.006714           0.030929    0.010915
# 11  features42           400.952911           0.026107    0.009213
# 12  features14           398.140411           0.025924    0.009149
# 13  features26           355.344482           0.023138    0.008165
# 14   features7           323.115601           0.021039    0.007425
# 15  features22           280.190308           0.018244    0.006438
# 16  features55           229.367889           0.014935    0.005271
# 17   features5           218.694397           0.014240    0.005025
# 18  features46           213.962662           0.013932    0.004917
# 19  features19           174.911072           0.011389    0.004019
# See the whole table with table.as_data_frame()

# %%
print(model_xg.)
print(model_xg.)
print(model_xg.)
print(model_xg.)

# %% [markdown]
# ### Model Plot : metrics could be "logloss", "auc", "classification_error", "rmse", "objective", "negative_log_likelihood

# %%
import matplotlib

fig = model_xg.plot(metric = "auc")
fig

# %%
fig = model_xg.plot(metric = "rmse")

# %%
model_xg.plot(metric="roc")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~/anaconda3/envs/DistributedComputing/lib/python3.7/site-packages/h2o/utils/typechecks.py in _retrieve_assert_arguments()
#     517     try:
# --> 518         raise RuntimeError("Catch me!")
#     519     except RuntimeError:
#
# RuntimeError: Catch me!
#
# During handling of the above exception, another exception occurred:
#
# TokenError                                Traceback (most recent call last)
# <ipython-input-59-c30a918e9bb4> in <module>
# ----> 1 model_xg.plot(metric="roc")
#
# ~/anaconda3/envs/DistributedComputing/lib/python3.7/site-packages/h2o/model/binomial.py in plot(self, timestep, metric, server, **kwargs)
#     801         """
#     802         assert_is_type(metric, "AUTO", "logloss", "auc", "classification_error", "rmse", "objective",
# --> 803                        "negative_log_likelihood")
#     804         if self._model_json["algo"] in ("deeplearning", "deepwater", "xgboost", "drf", "gbm"):
#     805             # make sure metric is not those of GLM metrics for other models
#
# ~/anaconda3/envs/DistributedComputing/lib/python3.7/site-packages/h2o/utils/typechecks.py in assert_is_type(var, *types, **kwargs)
#     450     message = kwargs.get("message", None)
#     451     skip_frames = kwargs.get("skip_frames", 1)
# --> 452     args = _retrieve_assert_arguments()
#     453     vname = args[0]
#     454     etn = _get_type_name(expected_type, dump=", ".join(args[1:]))
#
# ~/anaconda3/envs/DistributedComputing/lib/python3.7/site-packages/h2o/utils/typechecks.py in _retrieve_assert_arguments()
#     536                 args_tokens = []
#     537                 level = 0
# --> 538                 for ttt in g:
#     539                     if step == 0:
#     540                         if ttt[0] != tokenize.NAME: continue
#
# ~/anaconda3/envs/DistributedComputing/lib/python3.7/tokenize.py in _tokenize(readline, encoding)
#     577         else:                                  # continued statement
#     578             if not line:
# --> 579                 raise TokenError("EOF in multi-line statement", (lnum, 0))
#     580             continued = 0
#     581
#
# TokenError: ('EOF in multi-line statement', (222, 0))

# %% [markdown]
# # All worked better than Linear Regression (Day3 - ex02) : 0.904408105251841
